# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('hidden_dim_2.csv')
df2 = pd.read_csv('hidden_dim_3.csv')
df3 = pd.read_csv('hidden_dim_4.csv')

df1 = df1[df1['support'] == 256000]
df2 = df2[df2['support'] == 256000]
df3 = df3[df3['support'] == 256000]

# %%
import numpy as np

metric = 'f1-score'
labels = df1['label']

x = np.arange(len(labels))
plt.figure(figsize=(30, 12))

width = 0.4
plt.bar(x - width/2, df1[metric], width, label='hidden_dim = 256', color='b')
plt.bar(x + width/2, df2[metric], width, label='hidden_dim = 512', color='skyblue')

plt.xlabel('Labels')
plt.ylabel(metric.capitalize())
plt.title(f'Comparison of {metric.capitalize()} between two different hidden dimension')

plt.xticks(x, labels, rotation='vertical')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

metric = 'f1-score'
labels = df1['label']

x = np.arange(len(labels))

plt.figure(figsize=(20, 10))
plt.plot(x, df1[metric], marker='o', label='hidden_dim = 256', color='b')
plt.plot(x, df2[metric], marker='o', label='hidden_dim = 512', color='r')
plt.plot(x, df3[metric], marker='o', label='hidden_dim = 1024', color='g')

plt.xlabel('Labels')
plt.ylabel(metric.capitalize())
plt.title(f'Comparison of {metric.capitalize()} between three CSV files')

plt.xticks(x, labels, rotation='vertical')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

metric = 'f1-score'
labels = df1['label']

x = np.arange(len(labels))

plt.figure(figsize=(20, 10))
plt.scatter(x, df1[metric], label='hidden_dim = 256', color='b')
plt.scatter(x, df2[metric], label='hidden_dim = 512', color='r')
plt.scatter(x, df3[metric], label='hidden_dim = 1024', color='g')

plt.xlabel('Labels')
plt.ylabel(metric.capitalize())
plt.title(f'Comparison of {metric.capitalize()} between three CSV files')
plt.xticks(x, labels, rotation='vertical')
plt.legend()

# 添加网格
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

metric = 'f1-score'
labels = df1['label']

x = np.arange(len(labels))

plt.figure(figsize=(20, 10))
plt.scatter(x, df1[metric], label='hidden_dim = 256', color='b')
plt.scatter(x, df2[metric], label='hidden_dim = 512', color='r')
plt.scatter(x, df3[metric], label='hidden_dim = 1024', color='g')

# 添加平均值的水平线
avg1 = df1[metric].mean()
avg2 = df2[metric].mean()
avg3 = df3[metric].mean()

# plt.axhline(y=avg1, color='b', linestyle='--', label='Avg. hidden_dim = 256')
plt.axhline(y=avg1, color='b', linestyle='--')
plt.axhline(y=avg2, color='r', linestyle='--')
plt.axhline(y=avg3, color='g', linestyle='--')

plt.xlabel('Labels')
plt.ylabel(metric.capitalize())
plt.title(f'Comparison of {metric.capitalize()} between three CSV files')
plt.xticks(x, labels, rotation='vertical')
plt.legend()

# 添加网格
plt.grid(True)

# 添加平均值的标签
plt.text(len(labels)+1, avg1, f'Avg. = {avg1:.2f}', color='b', va='center')
plt.text(len(labels)+1, avg2, f'Avg. = {avg2:.2f}', color='r', va='center')
plt.text(len(labels)+1, avg3, f'Avg. = {avg3:.2f}', color='g', va='center')

plt.show()
